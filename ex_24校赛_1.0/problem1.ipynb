# %%
# %load_ext autoreload
# %autoreload 1
# %aimport MModel

from MModel import MModel
import numpy as np

# %%
model = MModel(1)
model.reset_by_Kmeans(3)
best_cost = model.objective_function()

# %%
best_cost_ = model.simulated_annealing(initial_temp=100000, min_temp=1, alpha=0.95, max_iterations=50000)
best_cost = min(best_cost, best_cost_)
print("Best cost: ", best_cost)
# Out:
# Iteration 0: Cost = 11684531949.386002
# Iteration 100: Cost = 11684531949.386002
# Iteration 200: Cost = 11684531949.386002
# Iteration 300: Cost = 11684531949.386002
# Iteration 400: Cost = 11684531949.386002
# Iteration 500: Cost = 11684531949.386002
# Iteration 600: Cost = 11684531949.386002
# Iteration 700: Cost = 11684531949.386002
# Iteration 800: Cost = 11684531949.386002
# Iteration 900: Cost = 11684531949.386002
# Iteration 1000: Cost = 11684531949.386002
# Iteration 1100: Cost = 11684531949.386002
# Iteration 1200: Cost = 11684531949.386002
# Iteration 1300: Cost = 11684531949.386002
# Iteration 1400: Cost = 11684531949.386002
# Iteration 1500: Cost = 11684531949.386002
# Iteration 1600: Cost = 11684531949.386002
# Iteration 1700: Cost = 11684531949.386002
# Iteration 1800: Cost = 11684531949.386002
# Iteration 1900: Cost = 11684531949.386002
# Iteration 2000: Cost = 11684531949.386002
# Iteration 2100: Cost = 11684531949.386002
# Iteration 2200: Cost = 11684531949.386002
# ...
