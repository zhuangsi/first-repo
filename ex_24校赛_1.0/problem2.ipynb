# %%
# %load_ext autoreload
# %autoreload 1
# %aimport MModel

from MModel import MModel
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
model = MModel(2)
model.reset_by_Kmeans(10)
X = 0.8
best_cost = model.objective_function(X)

# %%
best_cost_ = model.simulated_annealing(initial_temp=10000, min_temp=1, alpha=0.95, max_iterations=50000, X=X)
best_cost = min(best_cost, best_cost_)
print("Best cost: ", best_cost)
# Out:
# Iteration 0: Cost = 61298846809.76872
# Iteration 100: Cost = 61298846809.76872
# Iteration 200: Cost = 61298846809.76872
# Iteration 300: Cost = 61298846809.76872
# Iteration 400: Cost = 61298846809.76872
# Iteration 500: Cost = 61298846809.76872
# Iteration 600: Cost = 61298846809.76872
# Iteration 700: Cost = 61298846809.76872
# Iteration 800: Cost = 61298846809.76872
# Iteration 900: Cost = 61298846809.76872
# Iteration 1000: Cost = 61298846809.76872
# Iteration 1100: Cost = 61298846809.76872
# Iteration 1200: Cost = 61298846809.76872
# Iteration 1300: Cost = 61298846809.76872
# Iteration 1400: Cost = 61298846809.76872
# Iteration 1500: Cost = 61298846809.76872
# Iteration 1600: Cost = 61298846809.76872
# Iteration 1700: Cost = 61298846809.76872
# Iteration 1800: Cost = 61298846809.76872
# Iteration 1900: Cost = 61298846809.76872
# Iteration 2000: Cost = 61298846809.76872
# Iteration 2100: Cost = 61298846809.76872
# Iteration 2200: Cost = 61298846809.76872
# ...

# %%
model.plot_result()
